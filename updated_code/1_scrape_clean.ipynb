# %% [markdown]
# # Step 1: Scraping and Cleaning
#
# In this notebook we are building the base of our database by scraping austrian startup listings on the following site:
#
# https://www.eu-startups.com/
#
# The following code will extract the information for each of the startups based on the listing example below:

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import time
import random
import re
import json

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=openai_api_key)

# %% [markdown]
# # 1.1 Scraping the listings
#
# ## Example Listing:
#
# ### Listing Example:
#
# <div style="text-align: center;">
#   <img src="../images/startupseu_listing.png" alt="Listing Example" width="80%">
# </div>
#
# ### HTML Structure:
#
# ```html
# <div id="wpbdp-listing-310342" class="wpbdp-listing">
#   <div class="listing-title">
#     <h3><a href="https://www.eu-startups.com/directory/digna-gmbh/">digna GmbH</a></h3>
#   </div>
#
#   <div class="excerpt-content">
#     <div class="listing-thumbnail">
#       <img src="https://www.eu-startups.com/wp-content/uploads/2024/08/digna-logo.png" alt="digna - data quality solution">
#     </div>
#
#     <div class="listing-details">
#       <div class="wpbdp-field-display wpbdp-field-business_name">
#         <span class="field-label">Business Name:</span>
#         <div class="value"><a href="#">digna GmbH</a></div>
#       </div>
#
#       <div class="wpbdp-field-display wpbdp-field-category">
#         <span class="field-label">Category:</span>
#         <div class="value"><a href="#">Austria</a></div>
#       </div>
#
#       <div class="wpbdp-field-display wpbdp-field-based_in">
#         <span class="field-label">Based in:</span>
#         <div class="value">Vienna</div>
#       </div>
#
#       <div class="wpbdp-field-display wpbdp-field-tags">
#         <span class="field-label">Tags:</span>
#         <div class="value">data quality, data observability tool, data quality solution, data warehouses, data centers</div>
#       </div>
#
#       <div class="wpbdp-field-display wpbdp-field-founded">
#         <span class="field-label">Founded:</span>
#         <div class="value">2020</div>
#       </div>
#     </div>
#   </div>
# </div>
# ```
#
# ### Extracted Fields:
#
# | Field | Value | Source |
# |-------|-------|--------|
# | **name** | digna GmbH | `<a>` tag in `.listing-title` |
# | **link** | https://www.eu-startups.com/directory/digna-gmbh/ | `href` attribute in `.listing-title > a` |
# | **category** | Austria | `.wpbdp-field-category .value` |
# | **based_in** | Vienna | `.wpbdp-field-based_in .value` |
# | **tags** | data quality, data observability tool, ... | `.wpbdp-field-tags .value` |
# | **founded** | 2020 | `.wpbdp-field-founded .value` |

# %% [markdown]
# ## Scraping initial listings

# %% [markdown]
# ### Scraping function
#
# This is the main scraping function used to extract all the listings from the directory, it works as follows:
#
# 1. Build the connection to the page using the requests library and initialize BeautifulSoup, the scraping tool.
#
# 2. Find all the matching containers, each representing a startup.
#
# 3. Extracting the information from the listings matching the HTML structure from above.

# %%
def extract_listings_from_page(url, headers=None):

    # 1. HTTP Get request to fetch the page content
    response = requests.get(url, headers=headers)
    response.raise_for_status()

    soup = BeautifulSoup(response.content, 'html.parser')
    
    # 2. Finding all the listing containers matching our pattern "wpbdp-listing-..."
    listings = soup.find_all('div', id=lambda value: value and value.startswith("wpbdp-listing-"))
    data = []

    for listing in listings:
        # Initialize a dictionary for this listing
        listing_data = {
            'name': None,
            'link': None,
            'category': None,
            'based_in': None,
            'tags': None,
            'founded': None
        }

        # 3. Extract data from each listing
        
        # 3.1 Extract name and link from the listing-title block
        title_div = listing.find('div', class_='listing-title')
        if title_div:
            a_tag = title_div.find('a')
            if a_tag:
                listing_data['name'] = a_tag.get_text(strip=True)
                listing_data['link'] = a_tag.get('href')
        
        # 3.2 Extract details from the listing-details block
        details_div = listing.find('div', class_='listing-details')
        if details_div:
            field_divs = details_div.find_all('div', class_=lambda x: x and "wpbdp-field-display" in x)
            for field in field_divs:
                label_span = field.find('span', class_='field-label')
                if not label_span:
                    continue
                # Normalize the label for matching
                label = label_span.get_text(strip=True).rstrip(':').lower()
                
                value_div = field.find('div', class_='value')
                value = value_div.get_text(strip=True) if value_div else None

                if label == 'business name':
                    continue
                elif label == 'category':
                    listing_data['category'] = value
                elif label == 'based in':
                    listing_data['based_in'] = value
                elif label == 'tags':
                    listing_data['tags'] = value
                elif label == 'founded':
                    listing_data['founded'] = value
        
        data.append(listing_data)
    
    return data

# %% [markdown]
# ### Scraping Process

# %%
# Define headers with a custom User-Agent to mimic a real browser.
headers = {
    'User-Agent': 'Mozilla/5.0 (compatible; MyScraper/1.0; +http://example.com/contact)'
}

base_url = "https://www.eu-startups.com/directory/wpbdp_category/austrian-startups/"

# %% [markdown]
# Here is an example on how the loop below works:

# %%
example_url = f"{base_url}page/50/"

example_page_listings = extract_listings_from_page(example_url, headers=headers)

pd.DataFrame.from_dict([example_page_listings[0]])
# Out:
#                name                                               link  \
# 0  FetoLife Science  https://www.eu-startups.com/directory/fetolife...
#
#   category based_in                                               tags founded
# 0  Austria   Vienna  Apps, Health Care, Medical, mHealth, Personal ...    2019

# %%
all_listings = []

# Loop trough all of the pages and scrape the data
for page in tqdm(range(1, 70), desc="Scraping pages"):
    # For page 1, use the base URL
    if page == 1:
        url = base_url
    # Construct the URL for other pages
    else:
        url = f"{base_url}page/{page}/"
    
    try:
        page_listings = extract_listings_from_page(url, headers=headers)
        all_listings.extend(page_listings)
    except Exception as e:
        print(f"Error scraping {url}: {e}")
    
    # Rate limiting: sleep for a random time between 1 to 3 seconds
    delay = random.uniform(1, 3)
    time.sleep(delay)

print("Total listings extracted:", len(all_listings))

# %% [markdown]
# ## Preprocessing
#
# To make our (my) life easier, let's do some preprocessing which looks as follows:
#
# 1. Converting it to a pandas dataframe and do some basic cleaning
#
# 2. Remove all the listings which are not in Austria using OpenAI API

# %% [markdown]
# ### Pandas Dataframe and Cleaning

# %%
df_listings = pd.read_csv("./data/eustartup_listings.csv")

# %%
df_listings = pd.DataFrame.from_dict(all_listings)

# Remove duplicates based on 'link' and 'name' columns
df_listings.drop_duplicates(subset=['link'], keep='first', inplace=True)
df_listings.drop_duplicates(subset=['name'], keep='first', inplace=True)

# Clean unusual line terminators found in the listings
def clean_unusual_terminators(text):
    if isinstance(text, str):
        return text.replace('\u2028', ' ').replace('\u2029', ' ')
    return text

df_listings = df_listings.map(clean_unusual_terminators)

# %% [markdown]
# ### Location filtering using OpenAI API
#
# Here we use ChatGPT (OpenAI API) to filter out non-austrian startups using the based_in columns. We also add the postal code and the region for further steps.

# %%
def classify_cities_openai(cities_list):
    
    prompt = f"""Given this list of city/location names from a startup database, please:
1. Identify which are Austrian locations (cities, towns, or regions in Austria)
2. Standardize the names to proper English spelling
3. Add the main postal code (PLZ) for each Austrian location
4. Add the Austrian federal state (Bundesland) for each location
5. Return a JSON object with two keys:
   - "austrian": a dict mapping original name -> {{"standardized": "English name", "postal_code": "PLZ", "region": "Bundesland"}}
   - "non_austrian": a list of locations not in Austria

Austrian federal states are: Vienna, Lower Austria, Upper Austria, Styria, Tyrol, Carinthia, Salzburg, Vorarlberg, Burgenland.
For regions or areas without a specific postal code, use the postal code of the main city in that region.

Cities to classify:
{json.dumps(cities_list)}"""

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        response_format={"type": "json_object"}
    )
    
    content = response.choices[0].message.content
    return json.loads(content)

# %%
# Get unique cities
unique_cities = df_listings['based_in'].dropna().unique().tolist()

# Classify with LLM and standardize
result = classify_cities_openai(unique_cities)

print("Austrian locations:", len(result['austrian']))
print("Non-Austrian locations:", len(result['non_austrian']))
# Out:
# Austrian locations: 100
# Non-Austrian locations: 24

# %% [markdown]
# Now we create a mapping and apply it to the dataframe:

# %%
# Create mappings
austrian_mapping = result['austrian']

# Create separate mappings for standardized names, postal codes, and regions
name_mapping = {k: v['standardized'] for k, v in austrian_mapping.items()}
postal_mapping = {k: v['postal_code'] for k, v in austrian_mapping.items()}
region_mapping = {k: v['region'] for k, v in austrian_mapping.items()}

# Filter to only Austrian locations
df_listings = df_listings[df_listings['based_in'].isin(austrian_mapping.keys())]

# Add postal code and region columns, then standardize city names
df_listings['postal_code'] = df_listings['based_in'].map(postal_mapping)
df_listings['region'] = df_listings['based_in'].map(region_mapping)
df_listings['based_in'] = df_listings['based_in'].map(name_mapping)

# %%
df_listings.reset_index(drop=True, inplace=True)
df_listings.head(3)
# Out:
#                         name  \
# 0  Yumi42 – Growth Made Easy
# 1                    Krajete
# 2               Submit Ninja
#
#                                                 link category  based_in  \
# 0  https://www.eu-startups.com/directory/yumi42-g...  Austria    Vienna
# 1     https://www.eu-startups.com/directory/krajete/  Austria  Pasching
# 2  https://www.eu-startups.com/directory/submit-n...  Austria    Vienna
#
#                                                 tags  founded postal_code  \
# 0                 coaching, marketplace, transparent     2025        1010
# 1  carbon capture, nox control, nox removal, Clea...     2025        4061
# 2  Marketing, Voice of customer, Customer Feedbac...     2025        1010
#
#           region
# 0         Vienna
# 1  Upper Austria
# 2         Vienna

# %%
df_listings.to_csv("./data/1_raw_listings.csv", index=False)
df_listings = pd.read_csv("./data/1_raw_listings.csv")

# %% [markdown]
# ## 1.2 Detailed Listing Scraping
#
# Now lets scrape the detailed listings for the startups we collected above, here is what an example page looks like:
#
# <div style="text-align: center;">
#   <img src="../images/startupseu_detailed_listing.png" alt="Detailed Listing" width="50%">
# </div>

# %% [markdown]
# ### Function

# %%
def extract_listing_details(url, headers=None):

    details = {
        'business_name': None,
        'logo_link': None,
        'long_business_description': None,
        'business_description': None,
        'total_funding': None,
        'website': None,
        'company_status': None,
        'social_links': []
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return details

    soup = BeautifulSoup(response.content, 'html.parser')
    
    # 1. Extract business name either from header or listing title
    header = soup.find('div', class_='td-page-header')
    if header:
        h1 = header.find('h1', class_='entry-title td-page-title')
        if h1:
            span = h1.find('span')
            if span:
                details['business_name'] = span.get_text(strip=True)
    if not details['business_name']:
        listing_title = soup.find('div', class_='listing-title')
        if listing_title:
            h2 = listing_title.find('h2')
            if h2:
                details['business_name'] = h2.get_text(strip=True)
    
    # 2. Get logo link from the thumbnail section
    thumbnail_div = soup.find('div', class_='listing-thumbnail')
    if thumbnail_div:
        a_tag = thumbnail_div.find('a')
        if a_tag:
            img_tag = a_tag.find('img')
            if img_tag and img_tag.get('src'):
                details['logo_link'] = img_tag.get('src')
    
    # 3. Helper function to extract field by its identifier
    def extract_field(field_identifier):
        field_div = soup.find('div', class_=lambda x: x and field_identifier in x)
        if field_div:
            value_div = field_div.find('div', class_='value')
            if value_div:
                return value_div.get_text(" ", strip=True)
        return None

    # 3.1 Long Business Description
    details['long_business_description'] = extract_field('wpbdp-field-long_business_description')

    # 3.2 Business Description
    details['business_description'] = extract_field('wpbdp-field-business_description')
    
    # 3.3 Total Funding
    details['total_funding'] = extract_field('wpbdp-field-total_funding')

    # 3.4 Website
    details['website'] = extract_field('wpbdp-field-website')
    
    # 3.5 Company Status
    details['company_status'] = extract_field('wpbdp-field-company_status')
    
    # 4. Social Links 
    social_container = soup.find('div', class_='social-fields')
    if social_container:
        anchor_tags = social_container.find_all('a')
        for a in anchor_tags:
            href = a.get('href')
            if href:
                details['social_links'].append(href)
    
    return details

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (compatible; MyScraper/1.0; +http://example.com/contact)'
}

detailed_rows = []

# Iterate over each row in our startup dataframe
for idx, row in tqdm(df_listings.iterrows(), total=len(df_listings), desc="Scraping details"):
    listing_url = row['link']
    
    # Extract additional details via our function
    details = extract_listing_details(listing_url, headers=headers)
    
    # Add the extracted details to the row
    combined_row = row.to_dict()
    combined_row.update(details)
    detailed_rows.append(combined_row)
    
    delay = random.uniform(2, 3)
    time.sleep(delay)

df_detailed_listings = pd.DataFrame(detailed_rows)
# Out:
# Scraping details from: https://www.eu-startups.com/directory/avdain/
# Sleeping for 2.14 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pdf-to-brainrot/
# Error fetching https://www.eu-startups.com/directory/pdf-to-brainrot/: 404 Client Error: Not Found for url: https://www.eu-startups.com/directory/pdf-to-brainrot/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/softgen/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/popper-power-gmbh/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/setter-ai/
# Sleeping for 2.98 seconds...
# Scraping details from: https://www.eu-startups.com/directory/surveysensum/
# Sleeping for 2.21 seconds...
# Scraping details from: https://www.eu-startups.com/directory/artypa/
# Sleeping for 2.76 seconds...
# Scraping details from: https://www.eu-startups.com/directory/share-your-party/
# Sleeping for 2.01 seconds...
# Scraping details from: https://www.eu-startups.com/directory/podpally/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pressure-washing-albany/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/no-title/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/wedding-capsule/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hyrox-training-plans/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dolphin-radar/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/506ai/
# Sleeping for 2.73 seconds...
# Scraping details from: https://www.eu-startups.com/directory/get-worksheet/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/finslice/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fantasygf-ai/
# Sleeping for 3.00 seconds...
# Scraping details from: https://www.eu-startups.com/directory/daiki-gmbh/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/caterme/
# Sleeping for 2.32 seconds...
# Scraping details from: https://www.eu-startups.com/directory/wasitai/
# Sleeping for 2.14 seconds...
# Scraping details from: https://www.eu-startups.com/directory/maps-scraper-ai/
# Sleeping for 2.08 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rtopilot/
# Sleeping for 2.14 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hypertxt/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cimphony/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digna-gmbh/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/idcanopy/
# Sleeping for 2.87 seconds...
# Scraping details from: https://www.eu-startups.com/directory/stomey-og/
# Sleeping for 2.80 seconds...
# Scraping details from: https://www.eu-startups.com/directory/aiones/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/permar-ai-inc/
# Sleeping for 2.98 seconds...
# Scraping details from: https://www.eu-startups.com/directory/evolushost/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dreampetsai/
# Sleeping for 2.01 seconds...
# Scraping details from: https://www.eu-startups.com/directory/linkedin-company-insights-by-arounddeal/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/jeanszilla/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/onetask/
# Sleeping for 2.84 seconds...
# Scraping details from: https://www.eu-startups.com/directory/weme-global/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/thinkvalue/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/simventure/
# Sleeping for 2.19 seconds...
# Scraping details from: https://www.eu-startups.com/directory/seven-bel/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/principia-mbs/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/praxilla/
# Sleeping for 2.76 seconds...
# Scraping details from: https://www.eu-startups.com/directory/n-vision/
# Sleeping for 2.42 seconds...
# Scraping details from: https://www.eu-startups.com/directory/moneycare/
# Sleeping for 2.29 seconds...
# Scraping details from: https://www.eu-startups.com/directory/metabolizeme/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/magmatic/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/logicdev/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/easy-month-end/
# Sleeping for 2.10 seconds...
# Scraping details from: https://www.eu-startups.com/directory/infrared.city
# Sleeping for 2.51 seconds...
# Scraping details from: https://www.eu-startups.com/directory/esg-chain/
# Sleeping for 2.39 seconds...
# Scraping details from: https://www.eu-startups.com/directory/enzyan-biocatalysis/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/energyfamily/
# Sleeping for 2.75 seconds...
# Scraping details from: https://www.eu-startups.com/directory/creonect/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bundre/
# Sleeping for 2.46 seconds...
# Scraping details from: https://www.eu-startups.com/directory/beat-shaper/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/apichamp/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tastemy.city
# Sleeping for 2.87 seconds...
# Scraping details from: https://www.eu-startups.com/directory/robotdreams/
# Sleeping for 2.08 seconds...
# Scraping details from: https://www.eu-startups.com/directory/redeem-solar-technologies/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/refinq/
# Sleeping for 2.42 seconds...
# Scraping details from: https://www.eu-startups.com/directory/optiviceenergy/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/myacker/
# Sleeping for 2.96 seconds...
# Scraping details from: https://www.eu-startups.com/directory/spacexpanse-multiverse/
# Sleeping for 2.00 seconds...
# Scraping details from: https://www.eu-startups.com/directory/herzensapp/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/glink/
# Sleeping for 2.40 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cyclebee/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/commonsun/
# Sleeping for 2.75 seconds...
# Scraping details from: https://www.eu-startups.com/directory/blue-auditor/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/biomotion/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bevi/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/beetle-fortech/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/plantarista/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/flapjack/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/escapecloud/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hololight/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/necture/
# Sleeping for 2.57 seconds...
# Scraping details from: https://www.eu-startups.com/directory/neara/
# Sleeping for 2.96 seconds...
# Scraping details from: https://www.eu-startups.com/directory/whalecard/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/spixnet/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/byeagain/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/damn-plastic/
# Sleeping for 2.98 seconds...
# Scraping details from: https://www.eu-startups.com/directory/parastruct/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/piktid/
# Sleeping for 2.52 seconds...
# Scraping details from: https://www.eu-startups.com/directory/schubu-systems/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/boolee/
# Sleeping for 2.32 seconds...
# Scraping details from: https://www.eu-startups.com/directory/youknowmebest/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/qualisent/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/passionclass/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sheetmagic/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/httpswwwbranding5com/
# Sleeping for 2.29 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fragdaspdf-simply-talk-to-any-pdf/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/feel-forever-young/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/aeromond/
# Sleeping for 2.35 seconds...
# Scraping details from: https://www.eu-startups.com/directory/timeular/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sagly/
# Sleeping for 2.90 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vigilios/
# Sleeping for 2.87 seconds...
# Scraping details from: https://www.eu-startups.com/directory/crmone/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/heybob/
# Sleeping for 2.49 seconds...
# Scraping details from: https://www.eu-startups.com/directory/whistle/
# Sleeping for 2.99 seconds...
# Scraping details from: https://www.eu-startups.com/directory/coolin/
# Sleeping for 2.09 seconds...
# Scraping details from: https://www.eu-startups.com/directory/trendfeedr/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/alwritely/
# Sleeping for 2.04 seconds...
# Scraping details from: https://www.eu-startups.com/directory/godot/
# Sleeping for 2.83 seconds...
# Scraping details from: https://www.eu-startups.com/directory/destination360-destinations-with-value/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tidalbase/
# Sleeping for 2.03 seconds...
# Scraping details from: https://www.eu-startups.com/directory/no-fuzz-marketing/
# Sleeping for 2.51 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rebeccai/
# Sleeping for 2.75 seconds...
# Scraping details from: https://www.eu-startups.com/directory/destination360/
# Sleeping for 2.55 seconds...
# Scraping details from: https://www.eu-startups.com/directory/oscar-stories/
# Sleeping for 2.78 seconds...
# Scraping details from: https://www.eu-startups.com/directory/storypact/
# Sleeping for 2.39 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cloneit/
# Sleeping for 2.75 seconds...
# Scraping details from: https://www.eu-startups.com/directory/slamstr/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/glasskube/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/wiro-consulting/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/allstarsbot/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/etutee/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/emma-wanderer/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/consola-finance/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/brightmind-ai/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/autory/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/add-to-water/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/myculture-gmbh/
# Sleeping for 2.52 seconds...
# Scraping details from: https://www.eu-startups.com/directory/and-less/
# Sleeping for 2.80 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fertilabs-gmbh/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/personly/
# Sleeping for 2.20 seconds...
# Scraping details from: https://www.eu-startups.com/directory/voidsy/
# Sleeping for 2.66 seconds...
# Scraping details from: https://www.eu-startups.com/directory/silana/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ohana/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nuvo-2/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/metaloop/
# Sleeping for 2.05 seconds...
# Scraping details from: https://www.eu-startups.com/directory/heyqq-ask-away/
# Sleeping for 2.89 seconds...
# Scraping details from: https://www.eu-startups.com/directory/heyrise/
# Sleeping for 2.01 seconds...
# Scraping details from: https://www.eu-startups.com/directory/heldyn/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gate-space/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/flinn-comply/
# Sleeping for 2.45 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nxrt/
# Sleeping for 2.45 seconds...
# Scraping details from: https://www.eu-startups.com/directory/redev/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/revitalyze/
# Sleeping for 2.06 seconds...
# Scraping details from: https://www.eu-startups.com/directory/coachfident/
# Sleeping for 2.64 seconds...
# Scraping details from: https://www.eu-startups.com/directory/goddard-discovery/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/datogy-gmbh/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/prop-id-simply-real-estate/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fynk/
# Sleeping for 2.47 seconds...
# Scraping details from: https://www.eu-startups.com/directory/shomugo-gmbh/
# Sleeping for 2.80 seconds...
# Scraping details from: https://www.eu-startups.com/directory/crew26/
# Sleeping for 2.08 seconds...
# Scraping details from: https://www.eu-startups.com/directory/reebuild/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/proofcheck/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pluz-care/
# Sleeping for 2.19 seconds...
# Scraping details from: https://www.eu-startups.com/directory/simplexx-web-solutions/
# Sleeping for 2.19 seconds...
# Scraping details from: https://www.eu-startups.com/directory/neolime/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lightning-company/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tuseca/
# Sleeping for 2.95 seconds...
# Scraping details from: https://www.eu-startups.com/directory/heylog/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/streamfire/
# Sleeping for 2.99 seconds...
# Scraping details from: https://www.eu-startups.com/directory/surfvacationer/
# Sleeping for 2.46 seconds...
# Scraping details from: https://www.eu-startups.com/directory/texterify/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/yourstyle/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kutschi-consulting/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/noumen/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/quork/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hello-inside/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/justmarkt/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/globalrisk/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/exo-one/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/celeris-therapeutics/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/etti-co/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/21bitcoin/
# Sleeping for 2.78 seconds...
# Scraping details from: https://www.eu-startups.com/directory/zone14/
# Sleeping for 2.71 seconds...
# Scraping details from: https://www.eu-startups.com/directory/xperience/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/windpuls/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vloor/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/viridad/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vinitor/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/trive-studio/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/testiny/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/medcom/
# Sleeping for 2.28 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sneakit/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/wpbdp_listing/sendance/
# Sleeping for 2.14 seconds...
# Scraping details from: https://www.eu-startups.com/directory/schrankerl/
# Sleeping for 2.69 seconds...
# Scraping details from: https://www.eu-startups.com/directory/roi4presenter/
# Sleeping for 2.57 seconds...
# Scraping details from: https://www.eu-startups.com/directory/openlaws/
# Sleeping for 2.49 seconds...
# Scraping details from: https://www.eu-startups.com/directory/notarity/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/netz-beweis/
# Sleeping for 2.70 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mjuks/
# Sleeping for 2.90 seconds...
# Scraping details from: https://www.eu-startups.com/directory/miracl-2/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/luminous-labs/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lets-connect/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/klarsicht/
# Sleeping for 2.94 seconds...
# Scraping details from: https://www.eu-startups.com/directory/keyone/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/myshopifystores/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/heartbeat-bio/
# Sleeping for 2.39 seconds...
# Scraping details from: https://www.eu-startups.com/directory/imd-biotech/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/futureweb/
# Sleeping for 2.39 seconds...
# Scraping details from: https://www.eu-startups.com/directory/econutri/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/delphi-data-labs/
# Sleeping for 2.80 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dark-forest/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/daphos/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cellectric-biosciences/
# Sleeping for 2.73 seconds...
# Scraping details from: https://www.eu-startups.com/directory/captic-io/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/beyond-now/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/auvaria/
# Sleeping for 2.99 seconds...
# Scraping details from: https://www.eu-startups.com/directory/artikuno/
# Sleeping for 2.46 seconds...
# Scraping details from: https://www.eu-startups.com/directory/arboretum-haus/
# Sleeping for 2.60 seconds...
# Scraping details from: https://www.eu-startups.com/directory/afreshed/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/24-sens/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/123-shared-mobility-holding-gmbh/
# Sleeping for 2.40 seconds...
# Scraping details from: https://www.eu-startups.com/directory/i-style-you-daily/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fermify/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/f-technologies/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/explore-with-us/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cambuildr/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ataleo/
# Sleeping for 2.78 seconds...
# Scraping details from: https://www.eu-startups.com/directory/artadvance/
# Sleeping for 2.57 seconds...
# Scraping details from: https://www.eu-startups.com/directory/arkeon-biotechnologies/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/arcletic/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/one-two-beer/
# Sleeping for 2.90 seconds...
# Scraping details from: https://www.eu-startups.com/directory/campstar/
# Sleeping for 2.50 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ada-growth/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/arkeon/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/affluens-group/
# Sleeping for 2.00 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lignovations/
# Sleeping for 2.69 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cyberaci/
# Sleeping for 2.61 seconds...
# Scraping details from: https://www.eu-startups.com/directory/crowdtiger/
# Sleeping for 2.47 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fua-investment-club/
# Sleeping for 2.80 seconds...
# Scraping details from: https://www.eu-startups.com/directory/exo-one-2/
# Sleeping for 2.08 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ettico/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hnow/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/leaders21com/
# Sleeping for 2.09 seconds...
# Scraping details from: https://www.eu-startups.com/directory/medcom-2/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mim-365/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mlxar/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/noreja/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/open-social-audio/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/propup/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/deeplynx/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bugbattle/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/algonist-biotechnologies/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/506-ai/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/shopstory/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/25superstars/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/coco-2/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gamble-verluste-ts-prozessfinanzierungs-gmbh/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/revo-foods/
# Sleeping for 2.06 seconds...
# Scraping details from: https://www.eu-startups.com/directory/helu-io/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/truendo-technologies/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/blackshark-ai-2/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/blue-monday-project/
# Sleeping for 2.21 seconds...
# Scraping details from: https://www.eu-startups.com/directory/recordee/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/seasy-gmbh/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ordito/
# Sleeping for 2.69 seconds...
# Scraping details from: https://www.eu-startups.com/directory/enspired/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/similio-media/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/relopilot/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/guestia/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/return-on-art/
# Sleeping for 2.06 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hellobello/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/drainbot/
# Sleeping for 2.51 seconds...
# Scraping details from: https://www.eu-startups.com/directory/blackshark-ai/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/enlivio/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/campstar-2/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mursall-active-coating-gmbh/
# Sleeping for 2.73 seconds...
# Scraping details from: https://www.eu-startups.com/directory/venturify/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tradersyard/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tech2impact/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/taxtastic/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/splitbee/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/splex/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/shion/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sanusx/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/san-group/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rotable-technologies/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rare-earth-games/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/quantics-gmbh/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/proxygen/
# Sleeping for 2.05 seconds...
# Scraping details from: https://www.eu-startups.com/directory/posedio/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nista-io/
# Sleeping for 2.66 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nexyo/
# Sleeping for 2.40 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mxr-tactics/
# Sleeping for 2.16 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mazing/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/marswalk/
# Sleeping for 2.21 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kickscale/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/jongerius-ecoduna/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/instigo/
# Sleeping for 2.95 seconds...
# Scraping details from: https://www.eu-startups.com/directory/infludata/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/numberx/
# Sleeping for 2.40 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hygiene-austria/
# Sleeping for 2.83 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gurkerl-at/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gleap/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/flasher/
# Sleeping for 2.78 seconds...
# Scraping details from: https://www.eu-startups.com/directory/findustrial/
# Sleeping for 2.06 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fairesleben/
# Sleeping for 2.96 seconds...
# Scraping details from: https://www.eu-startups.com/directory/factinsect/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digicust/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/danube-dynamics/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/competenz-lab/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cipacto/
# Sleeping for 2.52 seconds...
# Scraping details from: https://www.eu-startups.com/directory/carbon-cleanup/
# Sleeping for 2.29 seconds...
# Scraping details from: https://www.eu-startups.com/directory/brusli/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digital-schneiderei/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bank99/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/atmoky/
# Sleeping for 2.09 seconds...
# Scraping details from: https://www.eu-startups.com/directory/amrax/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/alwyzon/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sola-diagnostics/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/streak/
# Sleeping for 2.45 seconds...
# Scraping details from: https://www.eu-startups.com/directory/streemfire/
# Sleeping for 2.28 seconds...
# Scraping details from: https://www.eu-startups.com/directory/jobchain/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/integrysign/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/myreha/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nano-influence/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hae-sh/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/green-cloud-nine/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/novem-gold/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/froots/
# Sleeping for 2.74 seconds...
# Scraping details from: https://www.eu-startups.com/directory/redem/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/repeato/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/s-a-m-technologies-gmbh/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/doma-market/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digiburn/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/simplify-art/
# Sleeping for 2.21 seconds...
# Scraping details from: https://www.eu-startups.com/directory/talent-more/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/careety/
# Sleeping for 2.99 seconds...
# Scraping details from: https://www.eu-startups.com/directory/calm-storm-ventures/
# Sleeping for 2.83 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vollville/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/wedress-collective-gmbh/
# Sleeping for 2.19 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ahoy-kapptn/
# Sleeping for 2.83 seconds...
# Scraping details from: https://www.eu-startups.com/directory/asigmo-gmbh/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/visplore/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/wiffme/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/studylia/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sophia-advisory/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sparcs/
# Sleeping for 2.64 seconds...
# Scraping details from: https://www.eu-startups.com/directory/audiomy-gmbh/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tht-biomaterials/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/luga-up/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/akedis-innovations/
# Sleeping for 2.47 seconds...
# Scraping details from: https://www.eu-startups.com/directory/crypto-ape/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/advolist/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/speaketto/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lawstar/
# Sleeping for 2.99 seconds...
# Scraping details from: https://www.eu-startups.com/directory/inoqo/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/probando/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/506/
# Sleeping for 2.31 seconds...
# Scraping details from: https://www.eu-startups.com/directory/s-a-m-technologies/
# Sleeping for 2.84 seconds...
# Scraping details from: https://www.eu-startups.com/directory/secondra-com/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/teledoc/
# Sleeping for 3.00 seconds...
# Scraping details from: https://www.eu-startups.com/directory/circly/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vr-motion-learning-gmbh-co-kg/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/reisenbauer-solutions-gmbh/
# Sleeping for 2.10 seconds...
# Scraping details from: https://www.eu-startups.com/directory/wedress-collective/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/smart-inspection/
# Sleeping for 2.16 seconds...
# Scraping details from: https://www.eu-startups.com/directory/shoepy/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kontractory-2/
# Sleeping for 2.91 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kontractory/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/holy-pit/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/glacier/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gateway-labs/
# Sleeping for 2.90 seconds...
# Scraping details from: https://www.eu-startups.com/directory/difacturo-gmbh/
# Sleeping for 2.69 seconds...
# Scraping details from: https://www.eu-startups.com/directory/devjobs-at-it-recruiting-gmbh/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tmia-gmbh/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vars/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/interactive-paper/
# Sleeping for 3.00 seconds...
# Scraping details from: https://www.eu-startups.com/directory/localrydes/
# Sleeping for 2.95 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digando/
# Sleeping for 2.78 seconds...
# Scraping details from: https://www.eu-startups.com/directory/zerolens/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/avisio/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/celantur/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/coinpanion/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digando-com-2/
# Sleeping for 2.08 seconds...
# Scraping details from: https://www.eu-startups.com/directory/xencio-gmbh/
# Sleeping for 2.75 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cannabrother-e-u/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pixofarm/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/g-st-antivirals/
# Sleeping for 2.35 seconds...
# Scraping details from: https://www.eu-startups.com/directory/meetfox/
# Sleeping for 2.49 seconds...
# Scraping details from: https://www.eu-startups.com/directory/world-data-lab/
# Sleeping for 2.50 seconds...
# Scraping details from: https://www.eu-startups.com/directory/woodspace/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vlinder/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/visualsearch/
# Sleeping for 2.94 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vipaso/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/viesure-innovation-center/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vibe-moves-you/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/veroo/
# Sleeping for 2.76 seconds...
# Scraping details from: https://www.eu-startups.com/directory/uloo-me/
# Sleeping for 2.91 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tttech-industrial/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/true-live/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/trever/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/thinkers-ai/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/teamstack/
# Sleeping for 2.04 seconds...
# Scraping details from: https://www.eu-startups.com/directory/suppliot/
# Sleeping for 2.20 seconds...
# Scraping details from: https://www.eu-startups.com/directory/store-room/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/staymate/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sproof/
# Sleeping for 2.01 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sprad/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/skinscreener/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/seamox-information-technologies/
# Sleeping for 2.31 seconds...
# Scraping details from: https://www.eu-startups.com/directory/runple/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rosterize/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rebel-meat/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/read-coop/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/quantego/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/qapture/
# Sleeping for 2.39 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pivot-earth/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/oumaigou/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/oterea/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/novasign/
# Sleeping for 2.80 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nodeventure/
# Sleeping for 2.53 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nextpart-security-intelligence/
# Sleeping for 2.03 seconds...
# Scraping details from: https://www.eu-startups.com/directory/madiscover/
# Sleeping for 2.87 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lunixo/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/legitary/
# Sleeping for 2.51 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kern-tec/
# Sleeping for 2.56 seconds...
# Scraping details from: https://www.eu-startups.com/directory/imperion/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/illwerke-vkw/
# Sleeping for 2.96 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gradient-zero/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/forgtin/
# Sleeping for 2.18 seconds...
# Scraping details from: https://www.eu-startups.com/directory/flight-levels-academy/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/enery/
# Sleeping for 2.31 seconds...
# Scraping details from: https://www.eu-startups.com/directory/eberhart/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/e-battery-systems/
# Sleeping for 2.66 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dreamwaves/
# Sleeping for 2.12 seconds...
# Scraping details from: https://www.eu-startups.com/directory/drainbot-2/
# Sleeping for 2.42 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digital-moulds/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/digando-com/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/deki/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/decidea-make-good-decisions-2/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/condignum/
# Sleeping for 2.10 seconds...
# Scraping details from: https://www.eu-startups.com/directory/coders-bay/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/chatcloud/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/brickwise/
# Sleeping for 2.16 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bonrepublic/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/birdshades/
# Sleeping for 2.96 seconds...
# Scraping details from: https://www.eu-startups.com/directory/arti/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/alveri/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/albajet-charter-gmbh-2/
# Sleeping for 2.83 seconds...
# Scraping details from: https://www.eu-startups.com/directory/aisemo/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ahead-bio/
# Sleeping for 2.04 seconds...
# Scraping details from: https://www.eu-startups.com/directory/krew/
# Sleeping for 2.98 seconds...
# Scraping details from: https://www.eu-startups.com/directory/liquidary-com/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/joinpoints/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/i4see-tech/
# Sleeping for 2.70 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mlreef/
# Sleeping for 2.64 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gropyus/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/oe-service/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fiskaly/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fauna/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pow-wow-entertainment/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pregenerate/
# Sleeping for 2.21 seconds...
# Scraping details from: https://www.eu-startups.com/directory/prop-id/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/quantro-therapeutics/
# Sleeping for 2.46 seconds...
# Scraping details from: https://www.eu-startups.com/directory/s1seven/
# Sleeping for 2.29 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dejure-technologies/
# Sleeping for 2.31 seconds...
# Scraping details from: https://www.eu-startups.com/directory/decidea-make-good-decisions/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sarcura/
# Sleeping for 2.96 seconds...
# Scraping details from: https://www.eu-startups.com/directory/signd-identity-2/
# Sleeping for 2.20 seconds...
# Scraping details from: https://www.eu-startups.com/directory/colivi/
# Sleeping for 2.47 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cloudomation/
# Sleeping for 2.49 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cnqrclub/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/clean-code-software/
# Sleeping for 2.31 seconds...
# Scraping details from: https://www.eu-startups.com/directory/stresscoach/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/synopticons/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/syn-trac/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/templeton-apus/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/warrify/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/xki-gmbh/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/xuuluux/
# Sleeping for 2.52 seconds...
# Scraping details from: https://www.eu-startups.com/directory/yolly/
# Sleeping for 2.73 seconds...
# Scraping details from: https://www.eu-startups.com/directory/trackbar/
# ...
# Sleeping for 2.84 seconds...
# Scraping details from: https://www.eu-startups.com/directory/startaparat/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/shark-bike/
# Sleeping for 2.70 seconds...
# Scraping details from: https://www.eu-startups.com/directory/helloplant/
# Sleeping for 2.93 seconds...
# Scraping details from: https://www.eu-startups.com/directory/timesheet/
# Sleeping for 2.91 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mynextgarage-gmbh/
# Sleeping for 2.98 seconds...
# Scraping details from: https://www.eu-startups.com/directory/aviloo/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/moonvision/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/music-traveler/
# Sleeping for 2.04 seconds...
# Scraping details from: https://www.eu-startups.com/directory/jetclass/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/newsadoo/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/base-energy/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/farmdok/
# Sleeping for 2.67 seconds...
# Scraping details from: https://www.eu-startups.com/directory/seven-seas-gear-gmbh/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/idwell/
# Sleeping for 2.46 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tribe/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/proactivaudio/
# Sleeping for 2.05 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hydroponic-fodder/
# Sleeping for 2.10 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dinster-at/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/quicktaxi/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/toolsense/
# Sleeping for 2.38 seconds...
# Scraping details from: https://www.eu-startups.com/directory/procfit/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/discuto/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/sixfold/
# Sleeping for 2.03 seconds...
# Scraping details from: https://www.eu-startups.com/directory/reposee/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/storyblok/
# Sleeping for 2.11 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mostly-ai/
# Sleeping for 2.99 seconds...
# Scraping details from: https://www.eu-startups.com/directory/toolsense-2/
# Sleeping for 2.91 seconds...
# Scraping details from: https://www.eu-startups.com/directory/storyblok-2/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bsurance-2/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/music-traveler-2/
# Sleeping for 2.69 seconds...
# Scraping details from: https://www.eu-startups.com/directory/votre/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hello-again-gmbh/
# Sleeping for 2.01 seconds...
# Scraping details from: https://www.eu-startups.com/directory/testify-gmbh/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/allcyte/
# Sleeping for 2.78 seconds...
# Scraping details from: https://www.eu-startups.com/directory/finmatics/
# Sleeping for 2.97 seconds...
# Scraping details from: https://www.eu-startups.com/directory/innerspace/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/leftshift-one/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/storebox/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/userbrain/
# Sleeping for 2.94 seconds...
# Scraping details from: https://www.eu-startups.com/directory/contextflow/
# Sleeping for 2.89 seconds...
# Scraping details from: https://www.eu-startups.com/directory/codejob-at/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/apex-ventures/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/waterdrop/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/enaible/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/roomchooser/
# Sleeping for 2.81 seconds...
# Scraping details from: https://www.eu-startups.com/directory/snapscreen/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/riskine/
# Sleeping for 2.74 seconds...
# Scraping details from: https://www.eu-startups.com/directory/pocketrocket-studio/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/jobrocker/
# Sleeping for 2.36 seconds...
# Scraping details from: https://www.eu-startups.com/directory/stereosense/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/steed-equine-monitoring-solutions-gmbh/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mimo/
# Sleeping for 2.03 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gostudent/
# Sleeping for 2.56 seconds...
# Scraping details from: https://www.eu-startups.com/directory/steadysense/
# Sleeping for 2.51 seconds...
# Scraping details from: https://www.eu-startups.com/directory/intellyo/
# Sleeping for 2.42 seconds...
# Scraping details from: https://www.eu-startups.com/directory/byrd/
# Sleeping for 2.82 seconds...
# Scraping details from: https://www.eu-startups.com/directory/7lytix/
# Sleeping for 2.01 seconds...
# Scraping details from: https://www.eu-startups.com/directory/roiforcio-gmbh/
# Sleeping for 2.09 seconds...
# Scraping details from: https://www.eu-startups.com/directory/roulette77/
# Sleeping for 2.76 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kivu-technologies/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nymea-io/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/playerhunter/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fretello/
# Sleeping for 2.05 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tubics/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/evologic-technologies/
# Sleeping for 2.70 seconds...
# Scraping details from: https://www.eu-startups.com/directory/enpulsion/
# Sleeping for 2.61 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hydrogrid/
# Sleeping for 2.39 seconds...
# Scraping details from: https://www.eu-startups.com/directory/schrott24/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/steadysense-2/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lamie/
# Sleeping for 2.60 seconds...
# Scraping details from: https://www.eu-startups.com/directory/prikkthe-next-level-of-crowdfunding/
# Sleeping for 2.91 seconds...
# Scraping details from: https://www.eu-startups.com/directory/webcp/
# Sleeping for 2.32 seconds...
# Scraping details from: https://www.eu-startups.com/directory/baningo-com/
# Sleeping for 2.61 seconds...
# Scraping details from: https://www.eu-startups.com/directory/knoyd/
# Sleeping for 2.55 seconds...
# Scraping details from: https://www.eu-startups.com/directory/daibau-gmbh/
# Sleeping for 2.07 seconds...
# Scraping details from: https://www.eu-startups.com/directory/app-radar/
# Sleeping for 2.40 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dealmatrix-gmbh/
# Sleeping for 2.55 seconds...
# Scraping details from: https://www.eu-startups.com/directory/teamecho/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/adverity/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cashpresso/
# Sleeping for 2.34 seconds...
# Scraping details from: https://www.eu-startups.com/directory/leadinvest/
# Sleeping for 2.15 seconds...
# Scraping details from: https://www.eu-startups.com/directory/waytation/
# Sleeping for 2.61 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hokify/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/medicus/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bikemap/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/corplife/
# Sleeping for 2.68 seconds...
# Scraping details from: https://www.eu-startups.com/directory/leichtgemacht/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hanfgarten/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/fortunes/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ubiq/
# Sleeping for 2.86 seconds...
# Scraping details from: https://www.eu-startups.com/directory/powunity/
# Sleeping for 2.25 seconds...
# Scraping details from: https://www.eu-startups.com/directory/playbrush/
# Sleeping for 2.62 seconds...
# Scraping details from: https://www.eu-startups.com/directory/gronda/
# Sleeping for 2.43 seconds...
# Scraping details from: https://www.eu-startups.com/directory/payuca/
# Sleeping for 2.70 seconds...
# Scraping details from: https://www.eu-startups.com/directory/presono/
# Sleeping for 2.89 seconds...
# Scraping details from: https://www.eu-startups.com/directory/x-news/
# Sleeping for 2.21 seconds...
# Scraping details from: https://www.eu-startups.com/directory/medicus-ai/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ready2order/
# Sleeping for 2.54 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ease-link/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/healcloud/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bikemap-2/
# Sleeping for 2.20 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rendity/
# Sleeping for 2.04 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ubiq-ai/
# Sleeping for 2.27 seconds...
# Scraping details from: https://www.eu-startups.com/directory/vira-therapeutics/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bitpanda-2/
# Sleeping for 2.55 seconds...
# Scraping details from: https://www.eu-startups.com/directory/storyclash/
# Sleeping for 2.64 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tapkey-gmbh/
# Sleeping for 2.08 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bspotted/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/usound/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bitpanda/
# Sleeping for 2.85 seconds...
# Scraping details from: https://www.eu-startups.com/directory/checkyeti/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/finnest/
# Sleeping for 2.70 seconds...
# Scraping details from: https://www.eu-startups.com/directory/cyberith/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/nuki/
# Sleeping for 2.14 seconds...
# Scraping details from: https://www.eu-startups.com/directory/global-rockstar/
# Sleeping for 2.88 seconds...
# Scraping details from: https://www.eu-startups.com/directory/journi/
# Sleeping for 2.47 seconds...
# Scraping details from: https://www.eu-startups.com/directory/zizoo-2/
# Sleeping for 2.47 seconds...
# Scraping details from: https://www.eu-startups.com/directory/flight4sale-com/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/breathe-ilo/
# Sleeping for 2.69 seconds...
# Scraping details from: https://www.eu-startups.com/directory/startus-insights/
# Sleeping for 2.20 seconds...
# Scraping details from: https://www.eu-startups.com/directory/evermede/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/platomics/
# Sleeping for 2.77 seconds...
# Scraping details from: https://www.eu-startups.com/directory/rouge-h2-engineering/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ixopay/
# Sleeping for 2.23 seconds...
# Scraping details from: https://www.eu-startups.com/directory/eologix/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/luke-roberts/
# Sleeping for 2.56 seconds...
# Scraping details from: https://www.eu-startups.com/directory/usound-2/
# Sleeping for 2.02 seconds...
# Scraping details from: https://www.eu-startups.com/directory/dienanny-at/
# Sleeping for 2.73 seconds...
# Scraping details from: https://www.eu-startups.com/directory/quest-global-technologies/
# Sleeping for 2.59 seconds...
# Scraping details from: https://www.eu-startups.com/directory/usersnap/
# Sleeping for 2.72 seconds...
# Scraping details from: https://www.eu-startups.com/directory/crate-io/
# Sleeping for 2.24 seconds...
# Scraping details from: https://www.eu-startups.com/directory/hello-stage/
# Sleeping for 2.61 seconds...
# Scraping details from: https://www.eu-startups.com/directory/robo-wunderkind/
# Sleeping for 2.48 seconds...
# Scraping details from: https://www.eu-startups.com/directory/keyper/
# Sleeping for 2.58 seconds...
# Scraping details from: https://www.eu-startups.com/directory/smashcast/
# Sleeping for 2.49 seconds...
# Scraping details from: https://www.eu-startups.com/directory/planradar/
# Sleeping for 2.26 seconds...
# Scraping details from: https://www.eu-startups.com/directory/anyline/
# Sleeping for 2.92 seconds...
# Scraping details from: https://www.eu-startups.com/directory/angermann-it-services-gmbh/
# Sleeping for 2.50 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tractive/
# Sleeping for 2.41 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kompany/
# Sleeping for 2.46 seconds...
# Scraping details from: https://www.eu-startups.com/directory/lingohub/
# Sleeping for 2.76 seconds...
# Scraping details from: https://www.eu-startups.com/directory/bitmovin/
# Sleeping for 2.37 seconds...
# Scraping details from: https://www.eu-startups.com/directory/samyak-buildcon/
# Sleeping for 2.44 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kompany-2/
# Sleeping for 2.17 seconds...
# Scraping details from: https://www.eu-startups.com/directory/mysugr/
# Sleeping for 2.22 seconds...
# Scraping details from: https://www.eu-startups.com/directory/ngojobs/
# Sleeping for 2.65 seconds...
# Scraping details from: https://www.eu-startups.com/directory/inismo/
# Sleeping for 2.84 seconds...
# Scraping details from: https://www.eu-startups.com/directory/tourradar/
# Sleeping for 2.79 seconds...
# Scraping details from: https://www.eu-startups.com/directory/textunited/
# Sleeping for 2.64 seconds...
# Scraping details from: https://www.eu-startups.com/directory/text-united/
# Sleeping for 2.33 seconds...
# Scraping details from: https://www.eu-startups.com/directory/smaxtec-animal-care-gmbh/
# Sleeping for 2.63 seconds...
# Scraping details from: https://www.eu-startups.com/directory/runtastic/
# Sleeping for 2.94 seconds...
# Scraping details from: https://www.eu-startups.com/directory/toolani/
# Sleeping for 2.51 seconds...
# Scraping details from: https://www.eu-startups.com/directory/matchoffice-osterreich/
# Sleeping for 2.30 seconds...
# Scraping details from: https://www.eu-startups.com/directory/kununu/
# Sleeping for 2.13 seconds...
# Scraping details from: https://www.eu-startups.com/directory/matchoffice-at-shared-space-wien/
# Sleeping for 2.07 seconds...

# %%
df_dl = pd.DataFrame(detailed_rows)

df_dl['social_links'] = df_dl['social_links'].apply(lambda x: tuple(x) if isinstance(x, list) else x)

df_dl.drop_duplicates(keep='first', inplace=True)

df_dl.drop_duplicates(subset=['link'], keep='first', inplace=True)

df_dl.reset_index(drop=True, inplace=True)

df_dl = df_dl.applymap(clean_unusual_terminators)

#df_dl.to_csv("data/eustartup_listings.csv", index=False)

df_detailed_listings = pd.read_csv("data/eustartup_listings.csv")

df_detailed_listings
# Out:
#                                    name  \
# 0                                Avdain
# 1                       PDF To Brainrot
# 2                               Softgen
# 3                     Popper Power GmbH
# 4                             Setter AI
# ..                                  ...
# 697                           Runtastic
# 698                             toolani
# 699              Matchoffice Österreich
# 700                              Kununu
# 701  MatchOffice.at / Shared Space Wien
#
#                                                   link category  \
# 0        https://www.eu-startups.com/directory/avdain/  Austria
# 1    https://www.eu-startups.com/directory/pdf-to-b...  Austria
# 2       https://www.eu-startups.com/directory/softgen/  Austria
# 3    https://www.eu-startups.com/directory/popper-p...  Austria
# 4     https://www.eu-startups.com/directory/setter-ai/  Austria
# ..                                                 ...      ...
# 697   https://www.eu-startups.com/directory/runtastic/  Austria
# 698     https://www.eu-startups.com/directory/toolani/  Austria
# 699  https://www.eu-startups.com/directory/matchoff...  Austria
# 700      https://www.eu-startups.com/directory/kununu/  Austria
# 701  https://www.eu-startups.com/directory/matchoff...  Austria
#
#                                               based_in  \
# 0                                               Vienna
# 1    245 Wo Lung Street, Fanling, North District, H...
# 2                                              Austria
# 3                                               Vienna
# 4                                                 Wien
# ..                                                 ...
# 697                                               Linz
# 698                                             Vienna
# 699                                               Wien
# 700                                             Vienna
# 701                                               Wien
#
#                                                   tags  founded  \
# 0                         Company, Startup, One Person   2020.0
# 1                                    AI,Video,Learning   2024.0
# 2              AI code assistant, full stack developer   2024.0
# 3                          EV, Battery, BESS, Charging   2022.0
# 4    AI, AI Agents, Sales & Marketing, AI SaaS, AI ...   2024.0
# ..                                                 ...      ...
# 697          Activity Tracker, Fitness app, Healthcare   2009.0
# 698       Online Calls Software, Connectivity, Telecom   2008.0
# 699                   Office rentals, Business centres   2008.0
# 700  Anonymous Feedback, Companies Rating, Reviews ...   2007.0
# 701                         coworking, office, austria   2004.0
#
#                           business_name  \
# 0                                Avdain
# 1                                   NaN
# 2                               Softgen
# 3                     Popper Power GmbH
# 4                             Setter AI
# ..                                  ...
# 697                           Runtastic
# 698                             toolani
# 699              Matchoffice Österreich
# 700                              Kununu
# 701  MatchOffice.at / Shared Space Wien
#
#                                              logo_link  \
# 0    https://www.eu-startups.com/wp-content/uploads...
# 1                                                  NaN
# 2    https://www.eu-startups.com/wp-content/uploads...
# 3    https://www.eu-startups.com/wp-content/uploads...
# 4    https://www.eu-startups.com/wp-content/uploads...
# ..                                                 ...
# 697  https://www.eu-startups.com/wp-content/uploads...
# 698  https://www.eu-startups.com/wp-content/uploads...
# 699  https://www.eu-startups.com/wp-content/uploads...
# 700  https://www.eu-startups.com/wp-content/uploads...
# 701  https://www.eu-startups.com/wp-content/uploads...
#
#                              long_business_description  \
# 0    Avdain is a enterprise that embodies a fusion ...
# 1                                                  NaN
# 2    Beyond a starter: Your complete project, ready...
# 3                                                  NaN
# 4    Speed matters when you want more sales. That’s...
# ..                                                 ...
# 697                                                NaN
# 698                                                NaN
# 699  Thanks to our many years of experience with of...
# 700                                                NaN
# 701  Funktionale und voll ausgestattete Coworking S...
#
#                                   business_description  \
# 0    Avdain is an technology company founded and so...
# 1                                                  NaN
# 2    Softgen is your AI Web App Developer. Describe...
# 3    Popper Power GmbH develops advanced energy sto...
# 4    Easy-to-use AI appointment setter for WhatsApp...
# ..                                                 ...
# 697  runtastic helps you to track your fitness acti...
# 698  toolani offers cheap international calling to ...
# 699  MatchOffice is a recognised player for the pla...
# 700  The Austria based company kununu offers a plat...
# 701                Coworking Wien - Shared Office Wien
#
#                  total_funding  \
# 0     No funding announced yet
# 1                          NaN
# 2     No funding announced yet
# 3    Between €500K-€ 1 million
# 4             Between €1-€100K
# ..                         ...
# 697                        NaN
# 698                        NaN
# 699   No funding announced yet
# 700                        NaN
# 701   No funding announced yet
#
#                                                website company_status  \
# 0                                           avdain.com         Active
# 1                                                  NaN            NaN
# 2                                  https://softgen.ai/         Active
# 3                                  www.popperpower.com         Active
# 4                            https://www.trysetter.com         Active
# ..                                                 ...            ...
# 697                           http://www.runtastic.com            NaN
# 698                            https://www.toolani.com            NaN
# 699                         https://www.matchoffice.at         Active
# 700                              http://www.kununu.com            NaN
# 701  https://www.matchoffice.at/mieten/coworking/wi...            NaN
#
#                                        social_links
# 0                                                ()
# 1                                                ()
# 2                                                ()
# 3    ('https://www.linkedin.com/company/86313916',)
# 4                                                ()
# ..                                              ...
# 697                                              ()
# 698                                              ()
# 699                                              ()
# 700                                              ()
# 701                                              ()
#
# [702 rows x 14 columns]
